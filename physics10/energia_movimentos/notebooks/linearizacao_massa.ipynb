# %% [markdown]
# <a href="https://colab.research.google.com/github/cacbarros/stem-labs/blob/main/physics10/energia_movimentos/notebooks/linearizacao_massa.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 1) Preparar pastas no Colab
# !mkdir -p src_graphics assets

# 2) Descarregar o script do GitHub (raw)
# !wget -q -O src_graphics/linearizacao_massa.py \
  https://raw.githubusercontent.com/cacbarros/stem-labs/main/physics10/energia_movimentos/src_graphics/linearizacao_massa.py

# 3) Executar o script e chamar a funcao (mostra + guarda PDF)
# %run src_graphics/linearizacao_massa.py
out_path, a, b = generate_linearization_plot(out_pdf="assets/linearizacao_plot.pdf", show=True, seed=0)
print("PDF gerado em:", out_path)
print("Ajuste: a =", a, "| b =", b)
# Out:
# Saved: ../assets/linearizacao_plot.pdf | a=0.249719 | b=0.011992
# PDF gerado em: assets/linearizacao_plot.pdf
# Ajuste: a = 0.24971881571698984 | b = 0.01199208604670733
